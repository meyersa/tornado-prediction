# %%
# %pip install requests aria2 netCDF4 numpy xarray
# Out:
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (2.32.3)
# Collecting aria2
#   Downloading aria2-0.0.1b0-py3-none-manylinux_2_17_x86_64.whl.metadata (28 kB)
# Collecting netCDF4
#   Downloading netCDF4-1.7.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.12/site-packages (1.26.4)
# Collecting xarray
#   Downloading xarray-2024.11.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests) (2024.8.30)
# Collecting cftime (from netCDF4)
#   Downloading cftime-1.6.4.post1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: packaging>=23.2 in /opt/conda/lib/python3.12/site-packages (from xarray) (24.2)
# Requirement already satisfied: pandas>=2.1 in /opt/conda/lib/python3.12/site-packages (from xarray) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas>=2.1->xarray) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas>=2.1->xarray) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas>=2.1->xarray) (2024.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=2.1->xarray) (1.16.0)
# Downloading aria2-0.0.1b0-py3-none-manylinux_2_17_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 4.6 MB/s eta 0:00:00:00:01
# Downloading netCDF4-1.7.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 10.9 MB/s eta 0:00:0000:01
# Downloading xarray-2024.11.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 1.9 MB/s eta 0:00:00ta 0:00:01
# Downloading cftime-1.6.4.post1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 261.9 kB/s eta 0:00:00 0:00:01
# Installing collected packages: cftime, aria2, netCDF4, xarray
# Successfully installed aria2-0.0.1b0 cftime-1.6.4.post1 netCDF4-1.7.2 xarray-2024.11.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import logging
import subprocess
import tarfile

# Setup logging
logging.basicConfig(level=logging.INFO,
                    format="%(asctime)s - %(levelname)s - %(message)s")

# Constants
DOWNLOAD_DATA = True
DATA_DIR = './data'  # Directory containing .tar.gz files
# Temporary file for download links
TMP_FILE = os.path.join(DATA_DIR, 'tmp.txt')
EXTRACT_DIR = os.path.join(DATA_DIR, 'extracted')

# Bucket and endpoint configuration
CUSTOM_ENDPOINT = "bbproxy.meyerstk.com/file"
APP = "TorNetBecauseZenodoSlow"  # Bucket name

# Ensure directories exist
os.makedirs(DATA_DIR, exist_ok=True)
os.makedirs(EXTRACT_DIR, exist_ok=True)


def download_links(links):
    """
    Download files from the provided links using aria2c.
    Uses a file named tmp.txt in DATA_DIR for links.
    """
    try:
        # Write links to tmp.txt
        with open(TMP_FILE, 'w') as file:
            file.writelines(link + '\n' for link in links)
        logging.info(f"Temporary file created: {TMP_FILE}")

        # Run aria2c to download files
        logging.info(f"Starting downloads for links: {', '.join(links)}")
        command = [
            "aria2c",
            "-j", "3",                # Download up to 3 files concurrently
            "-x", "16",               # Use up to 16 connections per file
            # "--console-log-level=info",
            "-s", "16",               # Split each file into 16 segments
            "--dir", DATA_DIR,        # Specify the download directory
            "-i", TMP_FILE            # Input file with download links
        ]
        subprocess.run(command, check=True)
        logging.info("Downloads completed successfully.")
    except Exception as e:
        logging.error(f"Error during download: {e}")
        exit(1)
    finally:
        if os.path.exists(TMP_FILE):
            os.remove(TMP_FILE)
            logging.info(f"Temporary file deleted: {TMP_FILE}")


def download_files_with_aria():
    """
    Download files from a public Backblaze B2 bucket served via a custom endpoint using aria2c.
    """
    logging.info("Starting download process with aria2c...")

    # # List of files to download
    file_list = [
        "tornet_2013.tar.gz",
        "tornet_2014.tar.gz",
        "tornet_2015.tar.gz",
        "tornet_2016.tar.gz",
        "tornet_2017.tar.gz",
        "tornet_2018.tar.gz",
        "tornet_2019.tar.gz",
        "tornet_2020.tar.gz",
        "tornet_2021.tar.gz",
        "tornet_2022.tar.gz",
    ]

    # Construct the public URLs
    links = [f"https://{CUSTOM_ENDPOINT}/{APP}/{file_name}" for file_name in file_list]
    # links = [
    #     "https://zenodo.org/records/12655719/files/tornet_2022.tar.gz",
    #     "https://zenodo.org/records/12655718/files/tornet_2021.tar.gz",
    #     "https://zenodo.org/records/12655717/files/tornet_2020.tar.gz",
    #     "https://zenodo.org/records/12655716/files/tornet_2019.tar.gz",
    #     "https://zenodo.org/records/12655187/files/tornet_2018.tar.gz",
    #     "https://zenodo.org/records/12655183/files/tornet_2017.tar.gz",
    #     "https://zenodo.org/records/12655179/files/tornet_2016.tar.gz",
    #     "https://zenodo.org/records/12655151/files/tornet_2015.tar.gz",
    #     "https://zenodo.org/records/12637032/files/tornet_2014.tar.gz",
    #     "https://zenodo.org/records/12636522/files/tornet_2013.tar.gz",
    #     "https://zenodo.org/records/12636522/files/catalog.csv",
    # ]
    
    # Filter out already downloaded files
    links_to_download = [
        link for link in links
        if not os.path.exists(os.path.join(DATA_DIR, os.path.basename(link)))
    ]

    if links_to_download:
        download_links(links_to_download)
    else:
        logging.info("All files already downloaded.")


def extract_local_tar_files():
    """
    Extract all .tar.gz files from the local DATA_DIR to EXTRACT_DIR.
    """
    logging.info("Starting extraction process...")
    for file_name in os.listdir(DATA_DIR):
        if file_name.endswith('.tar.gz'):
            file_path = os.path.join(DATA_DIR, file_name)
            logging.info(f'Extracting {file_path}...')
            with tarfile.open(file_path, 'r:gz') as tar:
                tar.extractall(path=EXTRACT_DIR)
            logging.info(f'Extracted {file_path} to {EXTRACT_DIR}')


if DOWNLOAD_DATA:
    download_files_with_aria()

# Call the function to process the local .tar.gz files
extract_local_tar_files()
# Out:
# 2024-12-04 15:31:28,772 - INFO - Starting download process with aria2c...
# 2024-12-04 15:31:28,860 - INFO - Temporary file created: ./data/tmp.txt
# 2024-12-04 15:31:28,861 - INFO - Starting downloads for links: https://bbproxy.meyerstk.com/file/TorNetBecauseZenodoSlow/tornet_2013.tar.gz, https://bbproxy.meyerstk.com/file/TorNetBecauseZenodoSlow/tornet_2014.tar.gz, https://bbproxy.meyerstk.com/file/TorNetBecauseZenodoSlow/tornet_2015.tar.gz, https://bbproxy.meyerstk.com/file/TorNetBecauseZenodoSlow/tornet_2016.tar.gz, https://bbproxy.meyerstk.com/file/TorNetBecauseZenodoSlow/tornet_2017.tar.gz, https://bbproxy.meyerstk.com/file/TorNetBecauseZenodoSlow/tornet_2018.tar.gz, https://bbproxy.meyerstk.com/file/TorNetBecauseZenodoSlow/tornet_2019.tar.gz, https://bbproxy.meyerstk.com/file/TorNetBecauseZenodoSlow/tornet_2020.tar.gz, https://bbproxy.meyerstk.com/file/TorNetBecauseZenodoSlow/tornet_2021.tar.gz, https://bbproxy.meyerstk.com/file/TorNetBecauseZenodoSlow/tornet_2022.tar.gz
# 12/04 15:31:28 [INFO] <<--- --- --- ---
#
# 12/04 15:31:28 [INFO]   --- --- --- ---
#
# 12/04 15:31:28 [INFO]   --- --- --- --->>
#
# 12/04 15:31:28 [INFO] aria2 1.37.0
#
# 12/04 15:31:28 [INFO] gcc 11.2.1 20211120
#   built by  x86_64-pc-linux-gnu
#   targeting x86_64-pc-linux-musl
#   on        Nov 27 2023 08:29:14
#
# 12/04 15:31:28 [INFO] Linux 5.15.167.4-microsoft-standard-WSL2 #1 SMP Tue Nov 5 00:21:55 UTC 2024 x86_64
#
# 12/04 15:31:28 [INFO] zlib/1.3.0.zlib-ng libxml2/2.12.1 sqlite3/3.44.1 OpenSSL/3.2.0 c-ares/1.22.1 libssh2/1.11.0
#
# 12/04 15:31:28 [INFO] Logging started.
#
# 12/04 15:31:28 [INFO] Checking configured addresses
#
# 12/04 15:31:28 [INFO] Not considered: 127.0.0.1
#
# 12/04 15:31:28 [INFO] Found configured address: 172.21.0.2
#
# 12/04 15:31:28 [INFO] Not considered: ::1
#
# 12/04 15:31:28 [INFO] Not considered: fe80::42:acff:fe15:2%eth0
#
# 12/04 15:31:28 [INFO] IPv4 configured=1, IPv6 configured=0
#
# 12/04 15:31:28 [NOTICE] Downloading 10 item(s)
#
# 12/04 15:31:28 [INFO] System trusted CA certificates were successfully added.
#
# 12/04 15:31:28 [INFO] CUID#7 - Resolving hostname bbproxy.meyerstk.com
#
# 12/04 15:31:28 [INFO] CUID#8 - Resolving hostname bbproxy.meyerstk.com
#
# 12/04 15:31:28 [INFO] CUID#9 - Resolving hostname bbproxy.meyerstk.com
#
# 12/04 15:31:29 [INFO] CUID#7 - Name resolution complete: bbproxy.meyerstk.com -> 104.21.28.106, 172.67.145.217
#
# 12/04 15:31:29 [INFO] CUID#7 - Connecting to 104.21.28.106:443
#
# 12/04 15:31:29 [INFO] CUID#8 - DNS cache hit: bbproxy.meyerstk.com -> 104.21.28.106, 172.67.145.217
#
# 12/04 15:31:29 [INFO] CUID#8 - Connecting to 104.21.28.106:443
#
# 12/04 15:31:29 [INFO] CUID#9 - DNS cache hit: bbproxy.meyerstk.com -> 104.21.28.106, 172.67.145.217
#
# 12/04 15:31:29 [INFO] CUID#9 - Connecting to 104.21.28.106:443
#
# 12/04 15:31:29 [INFO] CUID#9 - Requesting:
# GET /file/TorNetBecauseZenodoSlow/tornet_2015.tar.gz HTTP/1.1
# User-Agent: aria2/1.37.0
# Accept: */*,application/metalink4+xml,application/metalink+xml
# Host: bbproxy.meyerstk.com
# Want-Digest: SHA-512;q=1, SHA-256;q=1, SHA;q=0.1
#
#
#
# 12/04 15:31:29 [INFO] CUID#7 - Requesting:
# GET /file/TorNetBecauseZenodoSlow/tornet_2013.tar.gz HTTP/1.1
# User-Agent: aria2/1.37.0
# Accept: */*,application/metalink4+xml,application/metalink+xml
# Host: bbproxy.meyerstk.com
# Want-Digest: SHA-512;q=1, SHA-256;q=1, SHA;q=0.1
#
#
#
# 12/04 15:31:29 [INFO] CUID#8 - Requesting:
# GET /file/TorNetBecauseZenodoSlow/tornet_2014.tar.gz HTTP/1.1
# User-Agent: aria2/1.37.0
# Accept: */*,application/metalink4+xml,application/metalink+xml
# Host: bbproxy.meyerstk.com
# Want-Digest: SHA-512;q=1, SHA-256;q=1, SHA;q=0.1
#
#
#
# 12/04 15:31:29 [INFO] CUID#9 - Response received:
# HTTP/1.1 200
# Date: Wed, 04 Dec 2024 15:31:29 GMT
# Content-Type: application/octet-stream
# Content-Length: 17395624045
# Connection: keep-alive
# x-bz-file-name: tornet_2015.tar.gz
# x-bz-file-id: 4_z655387b7e22580c9953f0d18_f2229008d95e4cef8_d20241203_m182417_c000_v0001058_t0047_u01733250257777
# x-bz-content-sha1: none
# X-Bz-Upload-Timestamp: 1733250257777
# x-bz-info-large_file_sha1: e5961b5aeb2dde344cc30e392966cdf097dc5888
# x-bz-info-src_last_modified_millis: 1733249549178
# Strict-Transport-Security: max-age=63072000
# Cache-Control: max-age=14400
# CF-Cache-Status: MISS
# Last-Modified: Wed, 04 Dec 2024 15:31:29 GMT
# Report-To: {"endpoints":[{"url":"https:\/\/a.nel.cloudflare.com\/report\/v4?s=Nnhn5JUF8YYGEIouFbNZiCiiOt52S3heiKnDSlhUtC1nGC3QnD%2FpnapW4SSzjwgFVrADcs%2B2Mt2KMBOtVcbxdVFA53Y08v1h9mQhzltktA%2FPeePpNlOJiGA1unOLz%2F82bhLiZSlk2Q%3D%3D"}],"group":"cf-nel","max_age":604800}
# NEL: {"success_fraction":0,"report_to":"cf-nel","max_age":604800}
# Server: cloudflare
# CF-RAY: 8eccd7f9dbe2eb01-ORD
# alt-svc: h3=":443"; ma=86400
# server-timing: cfL4;desc="?proto=TCP&rtt=10108&min_rtt=9884&rtt_var=4156&sent=4&recv=6&lost=0&retrans=0&sent_bytes=2828&recv_bytes=852&delivery_rate=249957&cwnd=251&unsent_bytes=0&cid=9c9bf64a51229a75&ts=709&x=0"
#
#
#
# 12/04 15:31:29 [INFO] The segment file ./data/tornet_2015.tar.gz.aria2 does not exist.
#
# 12/04 15:31:29 [INFO] The segment file ./data/tornet_2015.tar.gz.aria2 does not exist.
#
# 12/04 15:31:29 [INFO] The segment file ./data/tornet_2015.tar.gz.aria2 does not exist.
#
# 12/04 15:31:29 [INFO] The segment file ./data/tornet_2015.tar.gz.aria2 does not exist.
#
# 12/04 15:31:29 [INFO] Dispatching FileAllocationCommand for CUID#10.
#
# 12/04 15:31:29 [NOTICE] Allocating disk space. Use --file-allocation=none to disable it. See --file-allocation option in man page for more details.
#
# 12/04 15:31:29 [INFO] CUID#8 - Response received:
# HTTP/1.1 200
# Date: Wed, 04 Dec 2024 15:31:29 GMT
# Content-Type: application/octet-stream
# Content-Length: 15066513529
# Connection: keep-alive
# x-bz-file-name: tornet_2014.tar.gz
# x-bz-file-id: 4_z655387b7e22580c9953f0d18_f2145ad689b6c3a0e_d20241203_m160359_c000_v0001400_t0059_u01733241839618
# x-bz-content-sha1: none
# X-Bz-Upload-Timestamp: 1733241839618
# x-bz-info-large_file_sha1: 2ff23939bbb610820907e6e2d7b91f07666fc7b9
# x-bz-info-src_last_modified_millis: 1733241113942
# Strict-Transport-Security: max-age=63072000
# Cache-Control: max-age=14400
# CF-Cache-Status: MISS
# Last-Modified: Wed, 04 Dec 2024 15:31:29 GMT
# Report-To: {"endpoints":[{"url":"https:\/\/a.nel.cloudflare.com\/report\/v4?s=g8W5YrawiqQLl3xzkrVbW2LrHpzUTapKJVobeA2jOK2u4SX4Pd51Fzk0inIDWvK%2BQPAiVc7pl6vGKA8HVXa3q9yNg0BGO%2B7OnfZTEoFP3p6OT%2BugH6yw0v3Ka3%2FqhI3f1oXe7PMlXw%3D%3D"}],"group":"cf-nel","max_age":604800}
# NEL: {"success_fraction":0,"report_to":"cf-nel","max_age":604800}
# Server: cloudflare
# CF-RAY: 8eccd7f9ee665074-ORD
# alt-svc: h3=":443"; ma=86400
# server-timing: cfL4;desc="?proto=TCP&rtt=9931&min_rtt=9662&rtt_var=3815&sent=4&recv=6&lost=0&retrans=0&sent_bytes=2829&recv_bytes=852&delivery_rate=302214&cwnd=249&unsent_bytes=0&cid=6a12c29a5c14438b&ts=825&x=0"
#
#
#
# 12/04 15:31:29 [INFO] The segment file ./data/tornet_2014.tar.gz.aria2 does not exist.
#
# 12/04 15:31:29 [INFO] The segment file ./data/tornet_2014.tar.gz.aria2 does not exist.
#
# 12/04 15:31:29 [INFO] The segment file ./data/tornet_2014.tar.gz.aria2 does not exist.
#
# 12/04 15:31:29 [INFO] The segment file ./data/tornet_2014.tar.gz.aria2 does not exist.
#
# 12/04 15:31:29 [INFO] CUID#7 - Response received:
# HTTP/1.1 200
# Date: Wed, 04 Dec 2024 15:31:29 GMT
# Content-Type: application/octet-stream
# Content-Length: 3159866899
# Connection: keep-alive
# x-bz-file-name: tornet_2013.tar.gz
# x-bz-file-id: 4_z655387b7e22580c9953f0d18_f208fc333cdc3a53e_d20241203_m150618_c000_v0001412_t0048_u01733238378835
# x-bz-content-sha1: none
# X-Bz-Upload-Timestamp: 1733238378835
# x-bz-info-large_file_sha1: 279a86f3722296ae3fc2c53bce9e916cd942dee2
# x-bz-info-src_last_modified_millis: 1733237989762
# Strict-Transport-Security: max-age=63072000
# Cache-Control: max-age=14400
# CF-Cache-Status: MISS
# Last-Modified: Wed, 04 Dec 2024 15:31:29 GMT
# Report-To: {"endpoints":[{"url":"https:\/\/a.nel.cloudflare.com\/report\/v4?s=UE4iINpN6e984TKlu%2Bp64JJZ8APtlB7053ADsPULZRr5UjDKlHwT8KsNngsO86RCwpMD54SP2X3Hcv7b8B2DDh0GuF2kS7xHJMpryaVk1erhHisnGlVi8CWL%2BEdMcMY8cJKxS4fMUA%3D%3D"}],"group":"cf-nel","max_age":604800}
# NEL: {"success_fraction":0,"report_to":"cf-nel","max_age":604800}
# Server: cloudflare
# CF-RAY: 8eccd7f9d94e112b-ORD
# alt-svc: h3=":443"; ma=86400
# server-timing: cfL4;desc="?proto=TCP&rtt=8730&min_rtt=8692&rtt_var=3336&sent=4&recv=6&lost=0&retrans=0&sent_bytes=2828&recv_bytes=852&delivery_rate=324408&cwnd=249&unsent_bytes=0&cid=cc4363c355177feb&ts=839&x=0"
#
#
#
# 12/04 15:31:29 [INFO] The segment file ./data/tornet_2013.tar.gz.aria2 does not exist.
#
# 12/04 15:31:29 [INFO] The segment file ./data/tornet_2013.tar.gz.aria2 does not exist.
#
# 12/04 15:31:29 [INFO] The segment file ./data/tornet_2013.tar.gz.aria2 does not exist.
#
# 12/04 15:31:29 [INFO] The segment file ./data/tornet_2013.tar.gz.aria2 does not exist.
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 25MiB/16GiB(0%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 249MiB/16GiB(1%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 482MiB/16GiB(2%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 641MiB/16GiB(3%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 756MiB/16GiB(4%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 880MiB/16GiB(5%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 920MiB/16GiB(5%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 0.9GiB/16GiB(5%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 0.9GiB/16GiB(5%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 0.9GiB/16GiB(5%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 1.0GiB/16GiB(6%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 1.1GiB/16GiB(6%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 1.1GiB/16GiB(7%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 1.3GiB/16GiB(8%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 1.5GiB/16GiB(9%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 1.8GiB/16GiB(11%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 2.0GiB/16GiB(12%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 2.0GiB/16GiB(12%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 2.0GiB/16GiB(12%)](+2)
#
# 12/04 15:32:29 [INFO] Saving the segment file ./data/tornet_2013.tar.gz.aria2
#
# 12/04 15:32:30 [INFO] The segment file was saved successfully.
#
# 12/04 15:32:30 [INFO] Saving the segment file ./data/tornet_2014.tar.gz.aria2
#
# 12/04 15:32:34 [INFO] The segment file was saved successfully.
#
# 12/04 15:32:48 [INFO] Saving the segment file ./data/tornet_2015.tar.gz.aria2
#
# 12/04 15:32:49 [INFO] The segment file was saved successfully.
#  *** Download Progress Summary as of Wed Dec  4 15:32:49 2024 ***
# ===============================================================================
# [#0a3b47 0B/2.9GiB(0%) CN:1 DL:0B]
# FILE: ./data/tornet_2013.tar.gz
# -------------------------------------------------------------------------------
# [#c2c979 0B/14GiB(0%) CN:1 DL:0B]
# FILE: ./data/tornet_2014.tar.gz
# -------------------------------------------------------------------------------
# [#7237f1 0B/16GiB(0%) CN:1 DL:0B]
# FILE: ./data/tornet_2015.tar.gz
# -------------------------------------------------------------------------------
#
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 2.1GiB/16GiB(12%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 2.2GiB/16GiB(14%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 2.2GiB/16GiB(14%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 2.4GiB/16GiB(15%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 2.7GiB/16GiB(16%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 2.7GiB/16GiB(16%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 2.7GiB/16GiB(16%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 2.8GiB/16GiB(17%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 3.0GiB/16GiB(18%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 3.0GiB/16GiB(18%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 3.0GiB/16GiB(18%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 3.0GiB/16GiB(18%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 3.0GiB/16GiB(18%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 3.0GiB/16GiB(18%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 3.0GiB/16GiB(18%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 3.0GiB/16GiB(18%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 3.0GiB/16GiB(18%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 3.1GiB/16GiB(19%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 3.1GiB/16GiB(19%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 3.3GiB/16GiB(20%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 3.3GiB/16GiB(20%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 3.3GiB/16GiB(20%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 3.3GiB/16GiB(20%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 3.3GiB/16GiB(20%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 3.3GiB/16GiB(20%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 3.3GiB/16GiB(20%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 3.5GiB/16GiB(21%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 3.5GiB/16GiB(21%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 3.5GiB/16GiB(21%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 3.6GiB/16GiB(22%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 3.8GiB/16GiB(23%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 3.9GiB/16GiB(24%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 4.2GiB/16GiB(25%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 4.2GiB/16GiB(26%)](+2)
#  *** Download Progress Summary as of Wed Dec  4 15:33:49 2024 ***
# ===============================================================================
# [#0a3b47 0B/2.9GiB(0%) CN:1 DL:0B]
# FILE: ./data/tornet_2013.tar.gz
# -------------------------------------------------------------------------------
# [#c2c979 0B/14GiB(0%) CN:1 DL:0B]
# FILE: ./data/tornet_2014.tar.gz
# -------------------------------------------------------------------------------
# [#7237f1 0B/16GiB(0%) CN:1 DL:0B]
# FILE: ./data/tornet_2015.tar.gz
# -------------------------------------------------------------------------------
#
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 4.5GiB/16GiB(27%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 4.6GiB/16GiB(28%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 4.8GiB/16GiB(30%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 5.1GiB/16GiB(31%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 5.2GiB/16GiB(32%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 5.2GiB/16GiB(32%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 5.2GiB/16GiB(32%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 5.2GiB/16GiB(32%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 5.2GiB/16GiB(32%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 5.3GiB/16GiB(32%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 5.3GiB/16GiB(33%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 5.4GiB/16GiB(33%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 5.5GiB/16GiB(34%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 5.5GiB/16GiB(34%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 5.5GiB/16GiB(34%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 5.7GiB/16GiB(35%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 5.9GiB/16GiB(37%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 6.2GiB/16GiB(38%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 6.4GiB/16GiB(39%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 6.6GiB/16GiB(41%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 6.8GiB/16GiB(42%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 7.0GiB/16GiB(43%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 7.0GiB/16GiB(43%)](+2)
#  *** Download Progress Summary as of Wed Dec  4 15:34:57 2024 ***
# ===============================================================================
# [#0a3b47 0B/2.9GiB(0%) CN:1 DL:0B]
# FILE: ./data/tornet_2013.tar.gz
# -------------------------------------------------------------------------------
# [#c2c979 0B/14GiB(0%) CN:1 DL:0B]
# FILE: ./data/tornet_2014.tar.gz
# -------------------------------------------------------------------------------
# [#7237f1 0B/16GiB(0%) CN:1 DL:0B]
# FILE: ./data/tornet_2015.tar.gz
# -------------------------------------------------------------------------------
#
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 7.1GiB/16GiB(43%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 7.1GiB/16GiB(43%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 7.1GiB/16GiB(43%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 7.2GiB/16GiB(44%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 7.4GiB/16GiB(46%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 7.7GiB/16GiB(47%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 7.8GiB/16GiB(48%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 7.8GiB/16GiB(48%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 7.9GiB/16GiB(48%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 7.9GiB/16GiB(48%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 7.9GiB/16GiB(48%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 7.9GiB/16GiB(48%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 7.9GiB/16GiB(49%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 8.1GiB/16GiB(50%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 8.2GiB/16GiB(51%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 8.2GiB/16GiB(51%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 8.3GiB/16GiB(51%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 8.6GiB/16GiB(53%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 8.7GiB/16GiB(53%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 8.7GiB/16GiB(54%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 9.0GiB/16GiB(55%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 9.2GiB/16GiB(57%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 9.3GiB/16GiB(57%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 9.5GiB/16GiB(59%)](+2)
#  *** Download Progress Summary as of Wed Dec  4 15:35:58 2024 ***
# ===============================================================================
# [#0a3b47 0B/2.9GiB(0%) CN:1 DL:0B]
# FILE: ./data/tornet_2013.tar.gz
# -------------------------------------------------------------------------------
# [#c2c979 0B/14GiB(0%) CN:1 DL:0B]
# FILE: ./data/tornet_2014.tar.gz
# -------------------------------------------------------------------------------
# [#7237f1 0B/16GiB(0%) CN:1 DL:0B]
# FILE: ./data/tornet_2015.tar.gz
# -------------------------------------------------------------------------------
#
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 9.6GiB/16GiB(59%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 9.6GiB/16GiB(59%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 9.6GiB/16GiB(59%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 9.6GiB/16GiB(59%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 9.6GiB/16GiB(59%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 9.6GiB/16GiB(59%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 9.9GiB/16GiB(61%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 10GiB/16GiB(62%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 10GiB/16GiB(62%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 10GiB/16GiB(62%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 10GiB/16GiB(62%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 10GiB/16GiB(62%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 10GiB/16GiB(62%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 10GiB/16GiB(62%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 10GiB/16GiB(62%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 10GiB/16GiB(63%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 10GiB/16GiB(64%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 10GiB/16GiB(64%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 10GiB/16GiB(64%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 10GiB/16GiB(64%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 10GiB/16GiB(64%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 10GiB/16GiB(64%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 10GiB/16GiB(65%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 10GiB/16GiB(66%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 10GiB/16GiB(66%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 10GiB/16GiB(66%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 10GiB/16GiB(66%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 10GiB/16GiB(67%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 10GiB/16GiB(67%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 10GiB/16GiB(67%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 11GiB/16GiB(69%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 11GiB/16GiB(69%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 11GiB/16GiB(69%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 11GiB/16GiB(69%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 11GiB/16GiB(69%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 11GiB/16GiB(69%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 11GiB/16GiB(69%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 11GiB/16GiB(69%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 11GiB/16GiB(70%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 11GiB/16GiB(71%)](+2)
#  *** Download Progress Summary as of Wed Dec  4 15:37:00 2024 ***
# ===============================================================================
# [#0a3b47 0B/2.9GiB(0%) CN:1 DL:0B]
# FILE: ./data/tornet_2013.tar.gz
# -------------------------------------------------------------------------------
# [#c2c979 0B/14GiB(0%) CN:1 DL:0B]
# FILE: ./data/tornet_2014.tar.gz
# -------------------------------------------------------------------------------
# [#7237f1 0B/16GiB(0%) CN:1 DL:0B]
# FILE: ./data/tornet_2015.tar.gz
# -------------------------------------------------------------------------------
#
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 11GiB/16GiB(71%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 11GiB/16GiB(71%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 11GiB/16GiB(71%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 11GiB/16GiB(72%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 11GiB/16GiB(73%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 11GiB/16GiB(73%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 11GiB/16GiB(73%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 11GiB/16GiB(73%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 11GiB/16GiB(73%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 11GiB/16GiB(73%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 11GiB/16GiB(73%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 11GiB/16GiB(73%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 11GiB/16GiB(73%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 12GiB/16GiB(74%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 12GiB/16GiB(76%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 12GiB/16GiB(77%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 12GiB/16GiB(77%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 12GiB/16GiB(77%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 12GiB/16GiB(77%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 12GiB/16GiB(77%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 12GiB/16GiB(79%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 13GiB/16GiB(80%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 13GiB/16GiB(81%)](+2)
#  *** Download Progress Summary as of Wed Dec  4 15:38:03 2024 ***
# ===============================================================================
# [#0a3b47 0B/2.9GiB(0%) CN:1 DL:0B]
# FILE: ./data/tornet_2013.tar.gz
# -------------------------------------------------------------------------------
# [#c2c979 0B/14GiB(0%) CN:1 DL:0B]
# FILE: ./data/tornet_2014.tar.gz
# -------------------------------------------------------------------------------
# [#7237f1 0B/16GiB(0%) CN:1 DL:0B]
# FILE: ./data/tornet_2015.tar.gz
# -------------------------------------------------------------------------------
#
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 13GiB/16GiB(81%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 13GiB/16GiB(81%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 13GiB/16GiB(82%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 13GiB/16GiB(83%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 13GiB/16GiB(83%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 13GiB/16GiB(84%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 13GiB/16GiB(85%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 13GiB/16GiB(86%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 13GiB/16GiB(86%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 13GiB/16GiB(86%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 14GiB/16GiB(86%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 14GiB/16GiB(87%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 14GiB/16GiB(87%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 14GiB/16GiB(87%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 14GiB/16GiB(88%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 14GiB/16GiB(88%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 14GiB/16GiB(89%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 14GiB/16GiB(91%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 15GiB/16GiB(92%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 15GiB/16GiB(94%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 15GiB/16GiB(95%)](+2)
#  *** Download Progress Summary as of Wed Dec  4 15:39:03 2024 ***
# ===============================================================================
# [#0a3b47 0B/2.9GiB(0%) CN:1 DL:0B]
# FILE: ./data/tornet_2013.tar.gz
# -------------------------------------------------------------------------------
# [#c2c979 0B/14GiB(0%) CN:1 DL:0B]
# FILE: ./data/tornet_2014.tar.gz
# -------------------------------------------------------------------------------
# [#7237f1 0B/16GiB(0%) CN:1 DL:0B]
# FILE: ./data/tornet_2015.tar.gz
# -------------------------------------------------------------------------------
#
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 15GiB/16GiB(95%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 15GiB/16GiB(95%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 15GiB/16GiB(95%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 15GiB/16GiB(95%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 15GiB/16GiB(95%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 15GiB/16GiB(96%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 15GiB/16GiB(96%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 15GiB/16GiB(96%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 15GiB/16GiB(96%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 15GiB/16GiB(97%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 15GiB/16GiB(97%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 15GiB/16GiB(97%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 15GiB/16GiB(97%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 15GiB/16GiB(98%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 15GiB/16GiB(98%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 15GiB/16GiB(98%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 15GiB/16GiB(98%)](+2)
#  *** Download Progress Summary as of Wed Dec  4 15:40:04 2024 ***
# ===============================================================================
# [#0a3b47 0B/2.9GiB(0%) CN:1 DL:0B]
# FILE: ./data/tornet_2013.tar.gz
# -------------------------------------------------------------------------------
# [#c2c979 0B/14GiB(0%) CN:1 DL:0B]
# FILE: ./data/tornet_2014.tar.gz
# -------------------------------------------------------------------------------
# [#7237f1 0B/16GiB(0%) CN:1 DL:0B]
# FILE: ./data/tornet_2015.tar.gz
# -------------------------------------------------------------------------------
#
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 16GiB/16GiB(99%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 16GiB/16GiB(99%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 16GiB/16GiB(99%)](+2)
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#7237f1 16GiB/16GiB(99%)](+2)
#
# 12/04 15:40:14 [INFO] Dispatching FileAllocationCommand for CUID#26.
# [DL:0B][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 0B/16GiB(0%)] [FileAlloc:#c2c979 0B/14GiB(0%)](+1)
#
# 12/04 15:40:14 [INFO] CUID#11 - DNS cache hit: bbproxy.meyerstk.com -> 104.21.28.106, 172.67.145.217
#
# 12/04 15:40:14 [INFO] CUID#11 - Connecting to 104.21.28.106:443
#
# 12/04 15:40:14 [INFO] CUID#12 - DNS cache hit: bbproxy.meyerstk.com -> 104.21.28.106, 172.67.145.217
#
# 12/04 15:40:14 [INFO] CUID#12 - Connecting to 104.21.28.106:443
#
# 12/04 15:40:14 [INFO] CUID#13 - DNS cache hit: bbproxy.meyerstk.com -> 104.21.28.106, 172.67.145.217
#
# 12/04 15:40:14 [INFO] CUID#13 - Connecting to 104.21.28.106:443
#
# 12/04 15:40:14 [INFO] CUID#14 - DNS cache hit: bbproxy.meyerstk.com -> 104.21.28.106, 172.67.145.217
#
# 12/04 15:40:14 [INFO] CUID#14 - Connecting to 104.21.28.106:443
#
# 12/04 15:40:14 [INFO] CUID#15 - DNS cache hit: bbproxy.meyerstk.com -> 104.21.28.106, 172.67.145.217
#
# 12/04 15:40:14 [INFO] CUID#15 - Connecting to 104.21.28.106:443
#
# 12/04 15:40:14 [INFO] CUID#16 - DNS cache hit: bbproxy.meyerstk.com -> 104.21.28.106, 172.67.145.217
#
# 12/04 15:40:14 [INFO] CUID#16 - Connecting to 104.21.28.106:443
#
# 12/04 15:40:14 [INFO] CUID#17 - DNS cache hit: bbproxy.meyerstk.com -> 104.21.28.106, 172.67.145.217
#
# 12/04 15:40:14 [INFO] CUID#17 - Connecting to 104.21.28.106:443
#
# 12/04 15:40:14 [INFO] CUID#18 - DNS cache hit: bbproxy.meyerstk.com -> 104.21.28.106, 172.67.145.217
#
# 12/04 15:40:14 [INFO] CUID#18 - Connecting to 104.21.28.106:443
#
# 12/04 15:40:14 [INFO] CUID#19 - DNS cache hit: bbproxy.meyerstk.com -> 104.21.28.106, 172.67.145.217
#
# 12/04 15:40:14 [INFO] CUID#19 - Connecting to 104.21.28.106:443
#
# 12/04 15:40:14 [INFO] CUID#20 - DNS cache hit: bbproxy.meyerstk.com -> 104.21.28.106, 172.67.145.217
#
# 12/04 15:40:14 [INFO] CUID#20 - Connecting to 104.21.28.106:443
#
# 12/04 15:40:14 [INFO] CUID#21 - DNS cache hit: bbproxy.meyerstk.com -> 104.21.28.106, 172.67.145.217
#
# 12/04 15:40:14 [INFO] CUID#21 - Connecting to 104.21.28.106:443
#
# 12/04 15:40:14 [INFO] CUID#22 - DNS cache hit: bbproxy.meyerstk.com -> 104.21.28.106, 172.67.145.217
#
# 12/04 15:40:14 [INFO] CUID#22 - Connecting to 104.21.28.106:443
#
# 12/04 15:40:14 [INFO] CUID#23 - DNS cache hit: bbproxy.meyerstk.com -> 104.21.28.106, 172.67.145.217
#
# 12/04 15:40:14 [INFO] CUID#23 - Connecting to 104.21.28.106:443
#
# 12/04 15:40:14 [INFO] CUID#24 - DNS cache hit: bbproxy.meyerstk.com -> 104.21.28.106, 172.67.145.217
#
# 12/04 15:40:14 [INFO] CUID#24 - Connecting to 104.21.28.106:443
#
# 12/04 15:40:14 [INFO] CUID#25 - DNS cache hit: bbproxy.meyerstk.com -> 104.21.28.106, 172.67.145.217
#
# 12/04 15:40:14 [INFO] CUID#25 - Connecting to 104.21.28.106:443
#
# 12/04 15:40:14 [INFO] CUID#11 - Requesting:
# GET /file/TorNetBecauseZenodoSlow/tornet_2015.tar.gz HTTP/1.1
# User-Agent: aria2/1.37.0
# Accept: */*
# Host: bbproxy.meyerstk.com
# Range: bytes=8697937920-9785311231
# Want-Digest: SHA-512;q=1, SHA-256;q=1, SHA;q=0.1
#
#
#
# 12/04 15:40:14 [INFO] CUID#12 - Requesting:
# GET /file/TorNetBecauseZenodoSlow/tornet_2015.tar.gz HTTP/1.1
# User-Agent: aria2/1.37.0
# Accept: */*
# Host: bbproxy.meyerstk.com
# Range: bytes=4349493248-5436866559
# Want-Digest: SHA-512;q=1, SHA-256;q=1, SHA;q=0.1
#
#
#
# 12/04 15:40:14 [INFO] CUID#13 - Requesting:
# GET /file/TorNetBecauseZenodoSlow/tornet_2015.tar.gz HTTP/1.1
# User-Agent: aria2/1.37.0
# Accept: */*
# Host: bbproxy.meyerstk.com
# Range: bytes=13047431168-14134804479
# Want-Digest: SHA-512;q=1, SHA-256;q=1, SHA;q=0.1
#
#
#
# 12/04 15:40:14 [INFO] CUID#15 - Requesting:
# GET /file/TorNetBecauseZenodoSlow/tornet_2015.tar.gz HTTP/1.1
# User-Agent: aria2/1.37.0
# Accept: */*
# Host: bbproxy.meyerstk.com
# Range: bytes=10872684544-11960057855
# Want-Digest: SHA-512;q=1, SHA-256;q=1, SHA;q=0.1
#
#
#
# 12/04 15:40:14 [INFO] CUID#16 - Requesting:
# GET /file/TorNetBecauseZenodoSlow/tornet_2015.tar.gz HTTP/1.1
# User-Agent: aria2/1.37.0
# Accept: */*
# Host: bbproxy.meyerstk.com
# Range: bytes=6524239872-7611613183
# Want-Digest: SHA-512;q=1, SHA-256;q=1, SHA;q=0.1
#
#
#
# 12/04 15:40:14 [INFO] CUID#17 - Requesting:
# GET /file/TorNetBecauseZenodoSlow/tornet_2015.tar.gz HTTP/1.1
# User-Agent: aria2/1.37.0
# Accept: */*
# Host: bbproxy.meyerstk.com
# Range: bytes=15222177792-16309551103
# Want-Digest: SHA-512;q=1, SHA-256;q=1, SHA;q=0.1
#
#
#
# 12/04 15:40:14 [INFO] CUID#18 - Requesting:
# GET /file/TorNetBecauseZenodoSlow/tornet_2015.tar.gz HTTP/1.1
# User-Agent: aria2/1.37.0
# Accept: */*
# Host: bbproxy.meyerstk.com
# Range: bytes=1087373312-2174746623
# Want-Digest: SHA-512;q=1, SHA-256;q=1, SHA;q=0.1
#
#
#
# 12/04 15:40:14 [INFO] CUID#20 - Requesting:
# GET /file/TorNetBecauseZenodoSlow/tornet_2015.tar.gz HTTP/1.1
# User-Agent: aria2/1.37.0
# Accept: */*
# Host: bbproxy.meyerstk.com
# Range: bytes=5436866560-6524239871
# Want-Digest: SHA-512;q=1, SHA-256;q=1, SHA;q=0.1
#
#
#
# 12/04 15:40:14 [INFO] CUID#21 - Requesting:
# GET /file/TorNetBecauseZenodoSlow/tornet_2015.tar.gz HTTP/1.1
# User-Agent: aria2/1.37.0
# Accept: */*
# Host: bbproxy.meyerstk.com
# Range: bytes=9785311232-10872684543
# Want-Digest: SHA-512;q=1, SHA-256;q=1, SHA;q=0.1
#
#
#
# 12/04 15:40:14 [INFO] CUID#22 - Requesting:
# GET /file/TorNetBecauseZenodoSlow/tornet_2015.tar.gz HTTP/1.1
# User-Agent: aria2/1.37.0
# Accept: */*
# Host: bbproxy.meyerstk.com
# Range: bytes=11960057856-13047431167
# Want-Digest: SHA-512;q=1, SHA-256;q=1, SHA;q=0.1
#
#
#
# 12/04 15:40:14 [INFO] CUID#23 - Requesting:
# GET /file/TorNetBecauseZenodoSlow/tornet_2015.tar.gz HTTP/1.1
# User-Agent: aria2/1.37.0
# Accept: */*
# Host: bbproxy.meyerstk.com
# Range: bytes=14134804480-15222177791
# Want-Digest: SHA-512;q=1, SHA-256;q=1, SHA;q=0.1
#
#
#
# 12/04 15:40:14 [INFO] CUID#24 - Requesting:
# GET /file/TorNetBecauseZenodoSlow/tornet_2015.tar.gz HTTP/1.1
# User-Agent: aria2/1.37.0
# Accept: */*
# Host: bbproxy.meyerstk.com
# Range: bytes=7611613184-8697937919
# Want-Digest: SHA-512;q=1, SHA-256;q=1, SHA;q=0.1
#
#
#
# 12/04 15:40:14 [INFO] CUID#25 - Requesting:
# GET /file/TorNetBecauseZenodoSlow/tornet_2015.tar.gz HTTP/1.1
# User-Agent: aria2/1.37.0
# Accept: */*
# Host: bbproxy.meyerstk.com
# Range: bytes=16309551104-17395624044
# Want-Digest: SHA-512;q=1, SHA-256;q=1, SHA;q=0.1
#
#
#
# 12/04 15:40:14 [INFO] CUID#14 - Requesting:
# GET /file/TorNetBecauseZenodoSlow/tornet_2015.tar.gz HTTP/1.1
# User-Agent: aria2/1.37.0
# Accept: */*
# Host: bbproxy.meyerstk.com
# Range: bytes=2174746624-3262119935
# Want-Digest: SHA-512;q=1, SHA-256;q=1, SHA;q=0.1
#
#
#
# 12/04 15:40:14 [INFO] CUID#19 - Requesting:
# GET /file/TorNetBecauseZenodoSlow/tornet_2015.tar.gz HTTP/1.1
# User-Agent: aria2/1.37.0
# Accept: */*
# Host: bbproxy.meyerstk.com
# Range: bytes=3262119936-4349493247
# Want-Digest: SHA-512;q=1, SHA-256;q=1, SHA;q=0.1
#
#
#
# 12/04 15:40:14 [INFO] CUID#9 - The download for one segment completed successfully.
#
# 12/04 15:40:14 [INFO] CUID#9 - The download for one segment completed successfully.
#
# 12/04 15:40:14 [INFO] CUID#9 - Restarting the download. URI=https://bbproxy.meyerstk.com/file/TorNetBecauseZenodoSlow/tornet_2015.tar.gz
# Exception: [AbstractCommand.cc:368] errorCode=1 URI=https://bbproxy.meyerstk.com/file/TorNetBecauseZenodoSlow/tornet_2015.tar.gz
#   -> [DownloadCommand.cc:234] errorCode=1 Got EOF from the server.
#
# 12/04 15:40:14 [INFO] CUID#9 - DNS cache hit: bbproxy.meyerstk.com -> 104.21.28.106, 172.67.145.217
#
# 12/04 15:40:14 [INFO] CUID#9 - Connecting to 104.21.28.106:443
#
# 12/04 15:40:14 [INFO] CUID#9 - Requesting:
# GET /file/TorNetBecauseZenodoSlow/tornet_2015.tar.gz HTTP/1.1
# User-Agent: aria2/1.37.0
# Accept: */*
# Host: bbproxy.meyerstk.com
# Range: bytes=2193132-1087373311
# Want-Digest: SHA-512;q=1, SHA-256;q=1, SHA;q=0.1
#
#
#
# 12/04 15:40:15 [INFO] CUID#13 - Response received:
# HTTP/1.1 206
# Date: Wed, 04 Dec 2024 15:40:14 GMT
# Content-Type: application/octet-stream
# Content-Length: 1087373312
# Connection: keep-alive
# x-bz-file-name: tornet_2015.tar.gz
# x-bz-file-id: 4_z655387b7e22580c9953f0d18_f2229008d95e4cef8_d20241203_m182417_c000_v0001058_t0047_u01733250257777
# x-bz-content-sha1: none
# X-Bz-Upload-Timestamp: 1733250257777
# x-bz-info-large_file_sha1: e5961b5aeb2dde344cc30e392966cdf097dc5888
# x-bz-info-src_last_modified_millis: 1733249549178
# Content-Range: bytes 13047431168-14134804479/17395624045
# Strict-Transport-Security: max-age=63072000
# Cache-Control: max-age=14400
# CF-Cache-Status: MISS
# Report-To: {"endpoints":[{"url":"https:\/\/a.nel.cloudflare.com\/report\/v4?s=GbM06ljleNn2QP0Jmmjn2iK3Dd5rezNyyBjn%2FsE05VrbAZ3Tj0mZHZ7%2BwQOh44mlYl9IR4qnBZ%2FFY2wxv4J4eYKSZXCoH4Cdt9K8GkAeVwnpD62u29eiIqMMI6vjcTbh3lTwGx%2B4RA%3D%3D"}],"group":"cf-nel","max_age":604800}
# NEL: {"success_fraction":0,"report_to":"cf-nel","max_age":604800}
# Server: cloudflare
# CF-RAY: 8ecce4cd386061bb-ORD
# alt-svc: h3=":443"; ma=86400
# server-timing: cfL4;desc="?proto=TCP&rtt=8778&min_rtt=8762&rtt_var=3318&sent=4&recv=5&lost=0&retrans=0&sent_bytes=2829&recv_bytes=839&delivery_rate=328311&cwnd=228&unsent_bytes=0&cid=2a8c6e2b49017d6f&ts=610&x=0"
#
#
#
# 12/04 15:40:15 [INFO] CUID#17 - Response received:
# HTTP/1.1 206
# Date: Wed, 04 Dec 2024 15:40:14 GMT
# Content-Type: application/octet-stream
# Content-Length: 1087373312
# Connection: keep-alive
# x-bz-file-name: tornet_2015.tar.gz
# x-bz-file-id: 4_z655387b7e22580c9953f0d18_f2229008d95e4cef8_d20241203_m182417_c000_v0001058_t0047_u01733250257777
# x-bz-content-sha1: none
# X-Bz-Upload-Timestamp: 1733250257777
# x-bz-info-large_file_sha1: e5961b5aeb2dde344cc30e392966cdf097dc5888
# x-bz-info-src_last_modified_millis: 1733249549178
# Content-Range: bytes 15222177792-16309551103/17395624045
# Strict-Transport-Security: max-age=63072000
# Cache-Control: max-age=14400
# CF-Cache-Status: MISS
# Report-To: {"endpoints":[{"url":"https:\/\/a.nel.cloudflare.com\/report\/v4?s=3cVeoBjiBy0vajHgpg7SSboTU0yi3qOOwkFCwcfIk9CwQQuK53gWmfZ1vDFWz32L%2B9XkCR38dgobf8R37Gj63vGGMlw40c1wWQ%2FRZGmvIr%2Fo%2Frn3G4FJ77kORAQl%2FJkOLenUJLJPCg%3D%3D"}],"group":"cf-nel","max_age":604800}
# NEL: {"success_fraction":0,"report_to":"cf-nel","max_age":604800}
# Server: cloudflare
# CF-RAY: 8ecce4cd49a8f851-ORD
# alt-svc: h3=":443"; ma=86400
# server-timing: cfL4;desc="?proto=TCP&rtt=8774&min_rtt=8723&rtt_var=3373&sent=4&recv=6&lost=0&retrans=0&sent_bytes=2827&recv_bytes=839&delivery_rate=319719&cwnd=251&unsent_bytes=0&cid=04be8ef654d174c1&ts=690&x=0"
#
#
#
# 12/04 15:40:15 [INFO] CUID#24 - Response received:
# HTTP/1.1 206
# Date: Wed, 04 Dec 2024 15:40:14 GMT
# Content-Type: application/octet-stream
# Content-Length: 1086324736
# Connection: keep-alive
# x-bz-file-name: tornet_2015.tar.gz
# ...
#
# 12/04 15:46:51 [INFO] CUID#13 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#25 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#12 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#22 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#16 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#23 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#20 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#18 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#21 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#15 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#17 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#11 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#24 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#9 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#19 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#14 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#13 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#25 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#12 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#22 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#16 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#23 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#20 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#18 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#21 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#15 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#17 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#11 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#24 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#9 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#19 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#14 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#13 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#25 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#12 - The download for one segment completed successfully.
#
# 12/04 15:46:51 [INFO] CUID#22 - The download for one segment completed successfully.
# [DL:38MiB][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 6.3GiB/16GiB(38%)] [FileAlloc:#c2c979 6.6GiB/14GiB(47%)](+1)
#
# 12/04 15:46:52 [INFO] CUID#16 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#23 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#20 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#18 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#21 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#15 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#17 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#11 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#24 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#9 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#19 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#14 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#13 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#25 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#12 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#22 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#16 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#23 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#20 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#18 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#21 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#15 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#17 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#24 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#11 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#9 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#19 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#14 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#13 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#25 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#12 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#22 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#16 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#23 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#20 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#18 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#21 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#15 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#17 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#24 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#11 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#9 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#14 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#19 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#13 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#25 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#12 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#22 - The download for one segment completed successfully.
#
# 12/04 15:46:52 [INFO] CUID#16 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#23 - The download for one segment completed successfully.
# [DL:39MiB][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 6.3GiB/16GiB(39%)] [FileAlloc:#c2c979 6.6GiB/14GiB(47%)](+1)
#
# 12/04 15:46:53 [INFO] CUID#20 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#18 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#21 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#15 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#17 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#24 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#11 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#9 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#14 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#19 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#13 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#25 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#12 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#22 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#16 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#23 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#20 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#18 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#21 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#15 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#17 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#24 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#11 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#9 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#14 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#19 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#13 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#25 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#12 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#22 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#16 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#23 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#20 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#18 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#21 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#15 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#17 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#24 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#11 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#9 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#14 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#19 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#13 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#25 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#12 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#22 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#16 - The download for one segment completed successfully.
#
# 12/04 15:46:53 [INFO] CUID#23 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#20 - The download for one segment completed successfully.
# [DL:41MiB][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 6.4GiB/16GiB(39%)] [FileAlloc:#c2c979 6.7GiB/14GiB(48%)](+1)
#
# 12/04 15:46:54 [INFO] CUID#18 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#21 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#15 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#17 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#24 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#11 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#9 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#14 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#19 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#13 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#25 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#12 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#22 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#16 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#23 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#20 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#18 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#21 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#15 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#17 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#24 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#9 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#11 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#14 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#13 - The download for one segment completed successfully.
#
# 12/04 15:46:54 [INFO] CUID#19 - The download for one segment completed successfully.
# [DL:39MiB][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 6.4GiB/16GiB(39%)] [FileAlloc:#c2c979 6.7GiB/14GiB(48%)](+1)
#
# 12/04 15:46:55 [INFO] CUID#25 - The download for one segment completed successfully.
#
# 12/04 15:46:55 [INFO] CUID#12 - The download for one segment completed successfully.
#
# 12/04 15:46:55 [INFO] CUID#22 - The download for one segment completed successfully.
#
# 12/04 15:46:55 [INFO] CUID#16 - The download for one segment completed successfully.
#
# 12/04 15:46:55 [INFO] CUID#23 - The download for one segment completed successfully.
#
# 12/04 15:46:55 [INFO] CUID#20 - The download for one segment completed successfully.
#
# 12/04 15:46:55 [INFO] CUID#18 - The download for one segment completed successfully.
# [DL:39MiB][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 6.4GiB/16GiB(39%)] [FileAlloc:#c2c979 6.7GiB/14GiB(48%)](+1)
#
# 12/04 15:46:56 [INFO] CUID#21 - The download for one segment completed successfully.
# [DL:3.2MiB][#0a3b47 0B/2.9GiB(0%)][#c2c979 0B/14GiB(0%)][#7237f1 6.4GiB/16GiB(39%)] [FileAlloc:#c2c979 6.7GiB/14GiB(48%)](+1)
#
# 12/04 15:47:03 [INFO] CUID#15 - The download for one segment completed successfully.
#
# 12/04 15:47:03 [INFO] CUID#17 - The download for one segment completed successfully.
#
# 12/04 15:47:03 [INFO] CUID#24 - The download for one segment completed successfully.
#
# 12/04 15:47:03 [INFO] CUID#9 - The download for one segment completed successfully.
#
# 12/04 15:47:03 [INFO] CUID#11 - The download for one segment completed successfully.
#
# 12/04 15:47:03 [INFO] CUID#14 - The download for one segment completed successfully.
#
# 12/04 15:47:03 [INFO] CUID#13 - The download for one segment completed successfully.
#
# 12/04 15:47:03 [INFO] CUID#19 - The download for one segment completed successfully.

# %%
import os
import xarray as xr
import numpy as np

VARIABLES = ['DBZ', 'VEL', 'KDP', 'RHOHV', 'ZDR', 'WIDTH']
TIME_STEPS = 3
SWEEPS = 2
IMAGE_HEIGHT = 120
IMAGE_WIDTH = 240

def load_nc_file(file_path):
    """
    Load a single NetCDF file and extract the required data and label.
    """
    with xr.open_dataset(file_path, engine="netcdf4") as ds:
        data = np.empty((IMAGE_HEIGHT, IMAGE_WIDTH, len(VARIABLES) * TIME_STEPS * SWEEPS), dtype=np.float32)
        idx = 0
        for t in range(TIME_STEPS):
            for s in range(SWEEPS):
                for var in VARIABLES:
                    channel_data = ds[var].isel(time=t, sweep=s).values
                    np.nan_to_num(channel_data, copy=False, nan=0, posinf=0, neginf=0)
                    data[:, :, idx] = channel_data
                    idx += 1
        label = 1 if 'TOR' in os.path.basename(file_path) else 0
    return data, label

def create_dataset(directory):
    """
    Load all NetCDF files from a directory and return arrays of data and labels.
    """
    data, labels = [], []
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.nc'):
                img, label = load_nc_file(os.path.join(root, file))
                data.append(img)
                labels.append(label)
    return np.array(data), np.array(labels)

# Dataset paths
TRAIN_DIR = os.path.join(EXTRACT_DIR, "train")
TEST_DIR = os.path.join(EXTRACT_DIR, "test")

# Load datasets
X_train, y_train = create_dataset(TRAIN_DIR)
X_test, y_test = create_dataset(TEST_DIR)

# Print dataset shapes
print(f"Train data shape: {X_train.shape}, Train labels shape: {y_train.shape}")
print(f"Test data shape: {X_test.shape}, Test labels shape: {y_test.shape}")
# Out:
# Train data shape: (0,), Train labels shape: (0,)
# Test data shape: (0,), Test labels shape: (0,)

# %%
from tensorflow.keras import models, layers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.metrics import Precision, Recall, AUC
from tensorflow.keras.regularizers import l2

# Model Definition
def create_torcnn(input_shape=(120, 240, 36), dropout_rate=0.3):
    """
    Define the CNN model for tornado detection.
    """
    model = models.Sequential([
        # Block 1
        layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=input_shape),
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout_rate),

        # Block 2
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout_rate),

        # Block 3
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout_rate),

        # Block 4
        layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(dropout_rate),

        # Fully Connected Layers
        layers.Flatten(),
        layers.Dense(128, activation='relu', kernel_regularizer=l2(0.01)),
        layers.BatchNormalization(),
        layers.Dropout(0.4),
        layers.Dense(64, activation='relu', kernel_regularizer=l2(0.01)),
        layers.BatchNormalization(),
        layers.Dropout(0.4),

        # Output Layer
        layers.Dense(1, activation='sigmoid')
    ])

    # Compile the model
    model.compile(
        optimizer=Adam(learning_rate=0.0005),
        loss=BinaryCrossentropy(),
        metrics=['accuracy', Precision(), Recall(), AUC()]
    )
    return model

# Create Model
input_shape = (120, 240, len(VARIABLES) * TIME_STEPS * SWEEPS)
model = create_torcnn(input_shape=input_shape)

# %%
BATCH_SIZE = 32
EPOCHS = 10

print("Starting model training...")
history = model.fit(
    X_train, y_train,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(X_test, y_test)
)

# %%
print("Evaluating the model...")
results = model.evaluate(X_test, y_test)
print(f"Test Loss: {results[0]}, Test Accuracy: {results[1]}")
